# %% [markdown]
# ## Brand Recommender based on an implicit ALS model
#
# To go through the code just point to the appropriate file path and hit shift+enter to run each cell. At the bottom of the page are some sample outputs as well but I have also attached a csv file with these predictions. I ran it on 4,185 brands out of the total number which is seen as the output called list1. The numerical value is the confidence that that brand is a match to the first brand which always has a confidence of 1. One unique property of ALS is that the confidence increases with a lower number of value counts. Ideally if I could discard values below a certain threshold of value counts.

# %%
import pandas as pd
import numpy as np
import scipy
from scipy.sparse import coo_matrix
import implicit

# %%
#Read in the data file
path = 'brands_filtered.txt'
df = pd.read_table(path, sep='\t')

# %% [markdown]
# Set up a 'values' column which assigns a 1 for each purchase of a brand by a user. Since there are many data points, I built a sparse matrix with coo_matrix which doesn't take up much memory.

# %%
def create_sparse(dataframe):
    dataframe['values'] = 1
    shopping_profile_id_u = list(np.sort(dataframe.shopping_profile_id.unique())) #Create sorted profile list
    brand_id_u = list(np.sort(dataframe.brand_id.unique())) #Create sorted brand list
    data = dataframe['values'].astype(float).tolist() #Create list of all the 1's I assigned for a purchase
    #Create row and column objects to build the sparse matrix with.
    row = dataframe.brand_id.astype('category', categories= brand_id_u).cat.codes 
    col = dataframe.shopping_profile_id.astype('category', categories=shopping_profile_id_u).cat.codes
    sparse = coo_matrix((data, (row, col)), shape=(len(brand_id_u), len(shopping_profile_id_u)))
    return sparse

# %%
sparse_matrix = create_sparse(df) #Create the sparse matrix

# %% [markdown]
# For the fitting of the model I would normally perform some form of a hyperparameter search in order to fine tune the algorithm but due to time constraints I stuck to the defaults.

# %%
def fit_model(sparse):
    model = implicit.als.AlternatingLeastSquares(factors=100)
    print "Fitting the model... \n"
    model.fit(sparse)
    print "Done!"
    return model

# %%
model = fit_model(sparse_matrix)
# Out:
# Fitting the model...
#
# Done!

# %% [markdown]
# This function takes the fitted model and the brand name that the user inputted and outputs the most similar brands to this one based off of the data given.

# %%
def predict(brand_name, models):
    unique_brands = np.sort(df.brand_id.unique())
    try:
        b_id = df.at[df[df['name']== brand_name].index[0], 'brand_id'] #get the brand id of the input
    except:
        print "brand does not exist"
    arr_val = np.where(unique_brands == b_id) #get the array position in the sparse matrix of the brand
    related = models.similar_items(arr_val[0][0]) #Feed the value into the similarity calculation of the model
    similar = []
    scores = []
    #Convert the sparse matrix positions back to brand names
    for i in related:
        value = int(i[0])
        scores.append(str(i[1]))
        similar_id = unique_brands[value]        
        similar.append(df.loc[df['brand_id'] == similar_id, 'name'].tolist()[0])
    return zip(similar, scores)

# %%
unique = df['name'].unique()
list1 = []
for name in unique[4186]:
    list1.append(predict(name, model))

# %%
list1
# Out:
# [[('BCBG MAX AZRIA', '1.0'),
#   ('MICHAEL Michael Kors', '0.212909063687'),
#   ('Steve Madden', '0.202693946502'),
#   ('Michael Kors', '0.16452204669'),
#   ('BCBGirls', '0.152628821119'),
#   ('Tory Burch', '0.145836928809'),
#   ('J.Crew', '0.138026052446'),
#   ('Isaac Mizrahi', '0.125207715556'),
#   ('Monique Lhuillier', '0.123510080443'),
#   ('Max Mara', '0.11830716188')],
#  [('Marc by Marc Jacobs', '1.0'),
#   ('Marc Jacobs', '0.384379272803'),
#   ('Burberry', '0.239677836706'),
#   ('Chlo\xc3\xa9', '0.212122521656'),
#   ('Diane von Furstenberg', '0.198390561418'),
#   ('Michael Kors', '0.187503188589'),
#   ('Jimmy Choo', '0.183985625036'),
#   ('Gucci', '0.180952325264'),
#   ('Yves Saint Laurent', '0.17006339849'),
#   ('Coach', '0.144591906596')],
#  [('Steve Madden', '1.0'),
#   ('MICHAEL Michael Kors', '0.25409016262'),
#   ('BCBG MAX AZRIA', '0.202693946502'),
#   ("Victoria's Secret", '0.175590497529'),
#   ('Forever 21', '0.164521141151'),
#   ('Christian Louboutin', '0.147495562648'),
#   ('Juicy Couture', '0.142743730491'),
#   ('GUESS', '0.130464266415'),
#   ('Madden-Girl', '0.126839684083'),
#   ('Marc by Marc Jacobs', '0.1242963209')],
#  [('Forever 21', '1.0'),
#   ("Victoria's Secret", '0.292474929424'),
#   ('Juicy Couture', '0.212473899601'),
#   ('GUESS', '0.200471033258'),
#   ('Steve Madden', '0.164521141151'),
#   ('Christian Louboutin', '0.133861021508'),
#   ('Wet Seal', '0.11041773668'),
#   ('BCBG MAX AZRIA', '0.101371948887'),
#   ('Charlotte Russe', '0.0983045932614'),
#   ('Urban Outfitters', '0.0897511337739')],
#  [("Victoria's Secret", '1.0'),
#   ('Forever 21', '0.292474929424'),
#   ('Juicy Couture', '0.261391279723'),
#   ('GUESS', '0.217963877342'),
#   ('Christian Louboutin', '0.198633024386'),
#   ('Steve Madden', '0.175590497529'),
#   ('Prada', '0.14508985503'),
#   ('Christian Dior', '0.140982463847'),
#   ('Calvin Klein', '0.120221420916'),
#   ('MICHAEL Michael Kors', '0.110889186716')],
#  [('Aldo', '1.0'),
#   ('Alloy', '0.248074592433'),
#   ('Arden B', '0.201194352766'),
#   ('The Body Shop', '0.180711007207'),
#   ('Nine West', '0.177173605391'),
#   ('Michael Antonio', '0.169036917482'),
#   ('Bebe', '0.1557018447'),
#   ('Maybelline', '0.155470887929'),
#   ("Delia's", '0.150823425679'),
#   ('Aeropostale', '0.150649182519')],
#  [('Newport News', '1.0'),
#   ('Spiegel', '0.958379210923'),
#   ('INC International Concepts', '0.823268323874'),
#   ('New York & Co.', '0.805773105856'),
#   ('Max Studio', '0.752143851761'),
#   ('Creative Recreation', '0.726340109138'),
#   ('White House', '0.724299121929'),
#   ('JS Boutique', '0.723588853087'),
#   ('Maggy London', '0.722848040438'),
#   ('Apt. 9', '0.72092773033')],
#  [('Miu Miu', '1.0'),
#   ('Mulberry', '0.212475568301'),
#   ('McQ by Alexander McQueen', '0.181212446508'),
#   ('Fendi', '0.178799856172'),
#   ('Prada', '0.175080231444'),
#   ('Anna Sui', '0.171981320139'),
#   ('Marni', '0.170628858586'),
#   ('Jil Sander', '0.163448637911'),
#   ('Philosophy di Alberta Ferretti', '0.16074796662'),
#   ('Anya Hindmarch', '0.153269686341')],
#  [('Moschino', '1.0'),
#   ('Anna Sui', '0.690484177656'),
#   ('Donna Karan', '0.590470420977'),
#   ('Carolina Herrera', '0.481804277611'),
#   ('Emporio Armani', '0.477078999999'),
#   ('G by Guess', '0.476810098339'),
#   ('Tommy Hilfiger', '0.467962966448'),
#   ('Hermes', '0.448412242409'),
#   ('McQ by Alexander McQueen', '0.4239853109'),
#   ('Mulberry', '0.410981051381')],
#  [('Mayle', '1.0'),
#   ('Katayone Adeli', '0.998142324956'),
#   ('Mark Davis', '0.994184462261'),
#   ('Subversive Jewelry', '0.99199566244'),
#   ('Chris Benz', '0.986132042073'),
#   ('TSE', '0.984557743283'),
#   ('Jonathan Saunders', '0.982595959888'),
#   ('Fallon', '0.981880230137'),
#   ('Roger Vivier', '0.980494776284'),
#   ('Pierre Hardy', '0.97589356885')],
#  [('McQ by Alexander McQueen', '1.0'),
#   ('Philosophy di Alberta Ferretti', '0.889660165026'),
#   ('Jil Sander', '0.862088666779'),
#   ('Mulberry', '0.858087847557'),
#   ('Derek Lam', '0.857459354083'),
#   ('Etro', '0.857438448506'),
#   ('Thakoon', '0.833401417272'),
#   ('Jill Stuart', '0.829298212088'),
#   ('Sergio Rossi', '0.820379916762'),
#   ('Dries Van Noten', '0.820048205074')],
#  [('Be & D', '1.0'),
#   ('Chris Benz', '0.939563178559'),
#   ('Fallon', '0.93785754195'),
#   ('Jonathan Saunders', '0.936229680757'),
#   ('Lee Angel', '0.935846768262'),
#   ('Mayle', '0.935239787106'),
#   ('Katayone Adeli', '0.935181171487'),
#   ('Mark Davis', '0.934538157879'),
#   ('Doo.Ri', '0.932724645602'),
#   ('Subversive Jewelry', '0.932622275428')],
#  [('Carolina Herrera', '1.0'),
#   ('Mulberry', '0.876891877838'),
#   ('Jil Sander', '0.865332889702'),
#   ('Jill Stuart', '0.857344301095'),
#   ('Derek Lam', '0.847754250195'),
#   ('Philosophy di Alberta Ferretti', '0.83738076946'),
#   ('Etro', '0.828318048594'),
#   ('Sergio Rossi', '0.817100210374'),
#   ('Peter Som', '0.80458275499'),
#   ('Hermes', '0.797088085109')],
#  [('Derek Lam', '1.0'),
#   ('Jil Sander', '0.983369803881'),
#   ('Dries Van Noten', '0.979282588652'),
#   ('Etro', '0.974425594145'),
#   ('Thakoon', '0.972343905608'),
#   ('Philosophy di Alberta Ferretti', '0.963932301654'),
#   ('The Row', '0.94559845262'),
#   ('Jill Stuart', '0.935200303371'),
#   ('Peter Som', '0.926486884962'),
#   ("L'Wren Scott", '0.924823840033')],
#  [('Erickson Beamon', '1.0'),
#   ('Tom Binns', '0.997835999275'),
#   ('Doo.Ri', '0.995473350132'),
#   ('Jonathan Saunders', '0.994322153413'),
#   ('Lee Angel', '0.994310045891'),
#   ('Chris Benz', '0.992435412938'),
#   ('Fallon', '0.991453629324'),
#   ("L'Wren Scott", '0.990440676529'),
#   ('Pierre Hardy', '0.987112215048'),
#   ('Roger Vivier', '0.981406603671')],
#  [('Eugenia Kim', '1.0'),
#   ('Halston', '0.745062761132'),
#   ('Karen Walker', '0.727844800224'),
#   ('Butter London', '0.709724295732'),
#   ('Full Tilt', '0.708298935644'),
#   ('Kenneth Jay Lane', '0.696824492051'),
#   ('Essie', '0.680693166869'),
#   ('Deborah Lippmann', '0.665243590503'),
#   ('Deepa Gurnani', '0.658735591463'),
#   ('Lush', '0.653951750584')],
#  [('Dries Van Noten', '1.0'),
#   ('Thakoon', '0.983097947998'),
#   ('Jil Sander', '0.981561402575'),
#   ('Etro', '0.980081317038'),
#   ('Derek Lam', '0.979282588652'),
#   ('The Row', '0.968347211562'),
#   ("L'Wren Scott", '0.960919454664'),
#   ('Doo.Ri', '0.958305122043'),
#   ('Erickson Beamon', '0.958066461338'),
#   ('A.P.C.', '0.956868462626')],
#  [('Diane von Furstenberg', '1.0'),
#   ('Christian Louboutin', '0.229690802006'),
#   ('Marc by Marc Jacobs', '0.198390561418'),
#   ('Jimmy Choo', '0.195660207857'),
#   ('Marc Jacobs', '0.156471281525'),
#   ('Chlo\xc3\xa9', '0.152435576317'),
#   ('Yves Saint Laurent', '0.142142678622'),
#   ('Trina Turk', '0.138085079525'),
#   ('Tory Burch', '0.136842297064'),
#   ('Parker', '0.13152314235')],
#  [('Kenneth Cole', '1.0'),
#   ('Kenneth Cole Reaction', '0.844221743252'),
#   ('INC International Concepts', '0.723375306159'),
#   ('Spiegel', '0.6873986986'),
#   ('Max Studio', '0.679219219233'),
#   ('Jones New York', '0.62993222851'),
#   ('Bed Bath & Beyond', '0.621738178429'),
#   ('Lucky Brand', '0.612255260866'),
#   ('Liz Claiborne', '0.611831264254'),
#   ('AK Anne Klein', '0.592757187223')],
#  [('Christian Louboutin', '1.0'),
#   ('Jimmy Choo', '0.296126334385'),
#   ('Yves Saint Laurent', '0.243860430798'),
#   ('Diane von Furstenberg', '0.229690802006'),
#   ("Victoria's Secret", '0.198633024386'),
#   ('Gucci', '0.189420896135'),
#   ('Chlo\xc3\xa9', '0.174076881175'),
#   ('Juicy Couture', '0.149970221416'),
#   ('Steve Madden', '0.147495562648'),
#   ('Marc by Marc Jacobs', '0.136032604306')],
#  [('Proenza Schouler', '1.0'),
#   ('Be & D', '0.742624440974'),
#   ('Peter Som', '0.705350458196'),
#   ('Marni', '0.694813755223'),
#   ('Dries Van Noten', '0.693284025629'),
#   ('Roger Vivier', '0.68086931983'),
#   ('The Row', '0.679775345394'),
#   ("L'Wren Scott", '0.676896727363'),
#   ('Karen Walker', '0.673946890895'),
#   ('Doo.Ri', '0.667767657501')],
#  [('Citizens of Humanity', '1.0'),
#   ("Joe's Jeans", '0.932471630549'),
#   ('Paige', '0.749789108159'),
#   ('Laundry by Shelli Segal', '0.746317334666'),
#   ('Rock & Republic', '0.736047975591'),
#   ('Ella Moss', '0.733243637192'),
#   ('James Perse', '0.731356763264'),
#   ('Martin + Osa', '0.699940455157'),
#   ('LaROK', '0.697842432865'),
#   ('Joie', '0.696430038383')],
#  [('Ella Moss', '1.0'),
#   ('Splendid', '0.875396670798'),
#   ('Twelfth St. By Cynthia Vincent', '0.874914447906'),
#   ('Joie', '0.869201606625'),
#   ('James Perse', '0.867102855875'),
#   ('LaROK', '0.815410345752'),
#   ('Robert Rodriguez', '0.79202507386'),
#   ('Trina Turk', '0.778367301518'),
#   ('Haute Hippie', '0.777388014571'),
#   ('Catherine Malandrino', '0.756700369137')],
#  [('Hanky Panky', '1.0'),
#   ('Three Dots', '0.99001434276'),
#   ('AG Jeans', '0.987726508442'),
#   ('Ali Ro', '0.987612773568'),
#   ('Michael Stars', '0.987237266557'),
#   ('Cosabella', '0.986713552813'),
#   ('Eberjey', '0.986578563439'),
#   ('Yumi Kim', '0.986147328539'),
#   ('Susana Monaco', '0.986046713289'),
#   ('Bop Basics', '0.985792849176')],
#  [('Jessica Simpson', '1.0'),
#   ('Maybelline', '0.283132259437'),
#   ('Revlon', '0.253193755417'),
#   ('Sally Hansen', '0.252527615228'),
#   ('Dooney & Bourke', '0.247771629435'),
#   ('Beach Sexy', '0.231428292306'),
#   ('Madden-Girl', '0.222694716187'),
#   ('Elle', '0.215692929825'),
#   ('The Body Shop', '0.215365594803'),
#   ('Toms', '0.212743086124')],
#  [('Juicy Couture', '1.0'),
#   ("Victoria's Secret", '0.261391279723'),
#   ('Forever 21', '0.212473899601'),
#   ('GUESS', '0.179690056594'),
#   ('Prada', '0.174358629743'),
#   ('Christian Louboutin', '0.149970221416'),
#   ('Steve Madden', '0.142743730491'),
#   ('Christian Dior', '0.126693449782'),
#   ('Dolce & Gabbana', '0.0988436142886'),
#   ('MICHAEL Michael Kors', '0.0969247053482')],
#  [('Nicole Miller', '1.0'),
#   ('ABS by Allen Schwartz', '0.412987693873'),
#   ('Adrianna Papell', '0.375386950426'),
#   ('New York & Co.', '0.354706671692'),
#   ('T-Bags', '0.348442599825'),
#   ('Newport News', '0.326488775531'),
#   ('LOFT', '0.324885319948'),
#   ('Tadashi Shoji', '0.315283350784'),
#   ('Jennifer Behr', '0.311601212847'),
#   ('Max Studio', '0.309343330192')],
#  [('Nike', '1.0'),
#   ('adidas', '0.646816842061'),
#   ('Puma', '0.607969894476'),
#   ('Revlon', '0.252238046734'),
#   ('Sperry', '0.243661948666'),
#   ("L'Oreal", '0.242808260089'),
#   ('Cover Girl', '0.234310389784'),
#   ('Lacoste', '0.228814939296'),
#   ('Fox', '0.226839100519'),
#   ('Sally Hansen', '0.225428489918')],
#  [('Nine West', '1.0'),
#   ('New York & Co.', '0.229965270351'),
#   ('LOFT', '0.222617357504'),
#   ('Neutrogena', '0.196629512462'),
#   ('Maybelline', '0.192049836864'),
#   ('Marc Jacobs', '0.191548013028'),
#   ('Fossil', '0.190514134047'),
#   ('Aldo', '0.177173605391'),
#   ('Clinique', '0.176494544189'),
#   ('Dooney & Bourke', '0.176015051846')],
#  [('Rock & Republic', '1.0'),
#   ('Citizens of Humanity', '0.736047975591'),
#   ('True Religion', '0.651104728865'),
#   ("Joe's Jeans", '0.650254428034'),
#   ('Lucky Brand', '0.61976876059'),
#   ('Cheap Monday', '0.514321966592'),
#   ('Ed Hardy', '0.492453210192'),
#   ('DSquared', '0.482425836501'),
#   ('GUESS by Marciano', '0.478630846165'),
#   ('Miss Me', '0.475597868833')],
#  [('Andrew Marc New York', '1.0'),
#   ('Rafe New York', '0.997171523077'),
#   ('Taryn Rose', '0.997052445094'),
#   ('Taryn by Taryn Rose', '0.996900182168'),
#   ('Josie Natori', '0.996887065904'),
#   ('Chaiken', '0.996623571843'),
#   ('Vivienne Tam', '0.996545439192'),
#   ('Adrienne Vittadini', '0.99650206905'),
#   ('Neiman Marcus', '0.996498754983'),
#   ('Design History', '0.996342622168')],
#  [('Bobbi Brown', '1.0'),
#   ('NARS', '0.839851403845'),
#   ('Benefit', '0.766355794928'),
#   ('Essie', '0.758825915043'),
#   ('M\xc2\xb7A\xc2\xb7C', '0.737171436276'),
#   ('Spanx', '0.73528114479'),
#   ('Urban Decay', '0.732306549402'),
#   ('Butter London', '0.712683580054'),
#   ('Lush', '0.707538608356'),
#   ('clarisonic', '0.664446667788')],
#  [('Burberry', '1.0'),
#   ('Gucci', '0.273794985387'),
#   ('Marc by Marc Jacobs', '0.239677836706'),
#   ('Marc Jacobs', '0.194957270601'),
#   ('Chlo\xc3\xa9', '0.187571716098'),
#   ('Prada', '0.178581439221'),
#   ('Jimmy Choo', '0.151898852171'),
#   ('Yves Saint Laurent', '0.148980089569'),
#   ('MICHAEL Michael Kors', '0.124558910897'),
#   ('Diane von Furstenberg', '0.120145859811')],
#  [('Chanel', '1.0'),
#   ('shu uemura', '0.193442068173'),
#   ('Vivienne Westwood', '0.191975626388'),
#   ('Oscar de la Renta', '0.190191245519'),
#   ('Emilio Pucci', '0.160918805572'),
#   ('Versace', '0.157912984792'),
#   ('Paul & Joe', '0.147549882479'),
#   ('Bulgari', '0.146437569438'),
#   ('Miu Miu', '0.145409845247'),
#   ('Alexander Mc Queen', '0.14400555974')],
#  [('Christian Dior', '1.0'),
#   ('Fendi', '0.225389520043'),
#   ('Lanc\xc3\xb4me', '0.208093808872'),
#   ('Prada', '0.194970965816'),
#   ('Carolina Herrera', '0.191170645937'),
#   ('Hermes', '0.186679832985'),
#   ('Gucci', '0.185864788391'),
#   ("L'Oreal", '0.180586497595'),
#   ('Clinique', '0.179405620392'),
#   ('Sergio Rossi', '0.170513382604')],
#  [('Coach', '1.0'),
#   ('Dooney & Bourke', '0.238403008767'),
#   ('Michael Kors', '0.209990397927'),
#   ('Carolina Herrera', '0.206047410502'),
#   ('Gap', '0.197861268596'),
#   ('Banana Republic', '0.194639942286'),
#   ('Donna Karan', '0.183141111586'),
#   ('Jill Stuart', '0.181053088281'),
#   ('Mulberry', '0.176751869726'),
#   ('DKNY', '0.173950537352')],
#  [('Ed Hardy', '1.0'),
#   ('Creative Recreation', '0.762332768007'),
#   ('G by Guess', '0.6770903497'),
#   ('Lucky Brand', '0.638667983587'),
#   ('GUESS by Marciano', '0.638101798994'),
#   ('Versace', '0.636956330881'),
#   ('Cheap Monday', '0.628896501456'),
#   ('Rampage', '0.578957724127'),
#   ('Hugo Boss', '0.570020499018'),
#   ('Faviana', '0.565135323952')],
#  [('Fendi', '1.0'),
#   ('Christian Dior', '0.225389520043'),
#   ('Prada', '0.201535439249'),
#   ('Gucci', '0.19012926775'),
#   ('Estee Lauder', '0.180675052444'),
#   ('Miu Miu', '0.178799856172'),
#   ('Mulberry', '0.170870963883'),
#   ('Carolina Herrera', '0.152478320076'),
#   ('Givenchy', '0.136373481432'),
#   ('Jil Sander', '0.133969677356')],
#  [('Giorgio Armani', '1.0'),
#   ('Nina Ricci', '0.96839890158'),
#   ('Blumarine', '0.959803492533'),
#   ('Narciso Rodriguez', '0.955614223519'),
#   ('Alberta Ferretti', '0.952659101077'),
#   ('Viktor & Rolf', '0.950082768674'),
#   ('Zac Posen', '0.947721288751'),
#   ('Giambattista Valli', '0.946947800948'),
#   ('Isaac Mizrahi', '0.940055569642'),
#   ('Emanuel Ungaro', '0.936600872532')],
#  [('Gucci', '1.0'),
#   ('Jimmy Choo', '0.396514441799'),
#   ('Marc Jacobs', '0.350937374201'),
#   ('Yves Saint Laurent', '0.342373632842'),
#   ('Chlo\xc3\xa9', '0.316654501026'),
#   ('Burberry', '0.273794985387'),
#   ('Fendi', '0.19012926775'),
#   ('Christian Louboutin', '0.189420896135'),
#   ('Christian Dior', '0.185864788391'),
#   ('Marc by Marc Jacobs', '0.180952325264')],
#  [('Hermes', '1.0'),
#   ('Carolina Herrera', '0.797088085109'),
#   ('Mulberry', '0.695201163234'),
#   ('Jil Sander', '0.640752330847'),
#   ('McQ by Alexander McQueen', '0.619145772726'),
#   ('Derek Lam', '0.599054570788'),
#   ('Jill Stuart', '0.582405514017'),
#   ('Etro', '0.580294523767'),
#   ('Philosophy di Alberta Ferretti', '0.565614812539'),
#   ('Peter Som', '0.551042595578')],
#  [('Jimmy Choo', '1.0'),
#   ('Gucci', '0.396514441799'),
#   ('Yves Saint Laurent', '0.383461494003'),
#   ('Chlo\xc3\xa9', '0.329203427303'),
#   ('Marc Jacobs', '0.327705425357'),
#   ('Christian Louboutin', '0.296126334385'),
#   ('Diane von Furstenberg', '0.195660207857'),
#   ('Marc by Marc Jacobs', '0.183985625036'),
#   ('Maybelline', '0.167383714645'),
#   ('Sephora', '0.161116993259')],
#  [('Juicy Couture Beach', '1.0'),
#   ('Juicy Couture Timepieces', '0.998596203589'),
#   ('Shades of Couture by Juicy Couture', '0.996948270188'),
#   ('Juice Beauty', '0.994216266176'),
#   ('Chip & Pepper', '0.992750794959'),
#   ('Jemma Kidd', '0.992587508534'),
#   ('Sexy Little Things', '0.992578208473'),
#   ('Elizabeth Taylor', '0.992558808863'),
#   ('Vanity Fair', '0.992525250416'),
#   ('BedHead', '0.992463213275')],
#  [('Juicy Couture Timepieces', '1.0'),
#   ('Juicy Couture Beach', '0.998596203589'),
#   ('Shades of Couture by Juicy Couture', '0.997393052166'),
#   ('Juice Beauty', '0.993835366039'),
#   ('Juicy Couture Kids', '0.992281169801'),
#   ('BedHead', '0.992146204587'),
#   ('Vanity Fair', '0.991996650045'),
#   ('Elizabeth Taylor', '0.991924299659'),
#   ('Cartier Fragrance', '0.991683792909'),
#   ('Jemma Kidd', '0.991669409895')],
#  [('Manolo Blahnik', '1.0'),
#   ('Sergio Rossi', '0.201615415161'),
#   ('Brian Atwood', '0.192803997142'),
#   ('Carolina Herrera', '0.167581089726'),
#   ('Christian Dior', '0.157401983084'),
#   ('Hermes', '0.147086972683'),
#   ('Spanx', '0.146712923184'),
#   ('Etro', '0.143730639961'),
#   ('Philosophy di Alberta Ferretti', '0.140408690676'),
#   ('Luella', '0.137045232212')],
#  [('Marc Jacobs', '1.0'),
#   ('Marc by Marc Jacobs', '0.384379272803'),
#   ('Gucci', '0.350937374201'),
#   ('Chlo\xc3\xa9', '0.339702445611'),
#   ('Jimmy Choo', '0.327705425357'),
#   ('Yves Saint Laurent', '0.305114142204'),
#   ('Clinique', '0.20665004972'),
#   ('Maybelline', '0.196641355753'),
#   ('Burberry', '0.194957270601'),
#   ('Michael Kors', '0.194794524711')],
#  [('Narciso Rodriguez', '1.0'),
#   ('Nina Ricci', '0.994231031552'),
#   ('Rodarte', '0.990182550305'),
#   ('Viktor & Rolf', '0.987952362347'),
#   ('Alberta Ferretti', '0.983937148327'),
#   ('Blumarine', '0.983155083745'),
#   ('Giambattista Valli', '0.983021631176'),
#   ('Emanuel Ungaro', '0.979650243461'),
#   ('Isaac Mizrahi', '0.973668147948'),
#   ('Zac Posen', '0.96790316953')],
#  [('Prada', '1.0'),
#   ('Hermes', '0.20854458893'),
#   ('Fendi', '0.201535439249'),
#   ('Christian Dior', '0.194970965816'),
#   ('Carolina Herrera', '0.186770131465'),
#   ('Mulberry', '0.183701203332'),
#   ('Calvin Klein', '0.17912693427'),
#   ('Burberry', '0.178581439221'),
#   ('Miu Miu', '0.175080231444'),
#   ('Juicy Couture', '0.174358629743')],
#  [('See by Chloe', '1.0'),
#   ('Paul & Joe', '0.346128370932'),
#   ('McQ by Alexander McQueen', '0.293777568736'),
#   ('Marni', '0.284158955822'),
#   ('Anna Sui', '0.250803198993'),
#   ('Repetto', '0.212883391537'),
#   ('Philosophy di Alberta Ferretti', '0.212578826904'),
#   ('Mulberry', '0.201006599273'),
#   ('shu uemura', '0.196705258958'),
#   ('Luella', '0.183771129744')],
#  [('Tory Burch', '1.0'),
#   ('Kate Spade', '0.199179143435'),
#   ('J.Crew', '0.183808799829'),
#   ('MICHAEL Michael Kors', '0.155790749736'),
#   ('Vince Camuto', '0.154515301435'),
#   ('Brian Atwood', '0.153286640057'),
#   ('BCBG MAX AZRIA', '0.145836928809'),
#   ('Diane von Furstenberg', '0.136842297064'),
#   ('Trina Turk', '0.135957554518'),
#   ('Toms', '0.134637819038')],
#  [('Trish McEvoy', '1.0'),
#   ('Dr. Hauschka Skin Care', '0.996797314027'),
#   ('Peter Thomas Roth', '0.996692754956'),
#   ('Jemma Kidd', '0.996636604826'),
#   ('K\xc3\xa9rastase', '0.996524987721'),
#   ('Molton Brown', '0.996479706413'),
#   ('DuWop', '0.99638430089'),
#   ('Ole Henriksen', '0.996359193149'),
#   ('Kevyn Aucoin', '0.996347099024'),
#   ('by Terry', '0.996262469137')],
#  [('True Religion', '1.0'),
#   ('Rock & Republic', '0.651104728865'),
#   ('Citizens of Humanity', '0.405952564719'),
#   ('Lucky Brand', '0.38181235641'),
#   ('Ed Hardy', '0.378630910581'),
#   ("Joe's Jeans", '0.302788012742'),
#   ('Clean & Clear', '0.251304893881'),
#   ('Cover Girl', '0.247700477608'),
#   ('Puma', '0.227774121574'),
#   ('Max Studio', '0.215044731436')],
#  [('Yves Saint Laurent', '1.0'),
#   ('Jimmy Choo', '0.383461494003'),
#   ('Chlo\xc3\xa9', '0.34759411513'),
#   ('Gucci', '0.342373632842'),
#   ('Marc Jacobs', '0.305114142204'),
#   ('Christian Louboutin', '0.243860430798'),
#   ('Urban Decay', '0.172860213313'),
#   ('Marc by Marc Jacobs', '0.17006339849'),
#   ('Maybelline', '0.167134761862'),
#   ('Estee Lauder', '0.162426613596')],
#  [('Arden B', '1.0'),
#   ('Jovani', '0.623365891816'),
#   ('ABS by Allen Schwartz', '0.573446260039'),
#   ('Adrianna Papell', '0.571544286249'),
#   ('Windsor', '0.506165097903'),
#   ('Alloy', '0.496828194084'),
#   ('Michael Antonio', '0.479096959035'),
#   ('Dave and Johnny', '0.472865425008'),
#   ('Rare', '0.458484206825'),
#   ('Faviana', '0.457497532426')],
#  [('Louis Vuitton', '1.0'),
#   ('Hermes', '0.439202289982'),
#   ('Carolina Herrera', '0.394214856458'),
#   ('Mulberry', '0.2766680286'),
#   ('Sergio Rossi', '0.242044081851'),
#   ('Derek Lam', '0.209191953041'),
#   ('Isaac Mizrahi', '0.20683627194'),
#   ('Jil Sander', '0.197931559648'),
#   ('Monique Lhuillier', '0.197594537062'),
#   ('Jill Stuart', '0.195071289892')],
#  [('Banana Republic', '1.0'),
#   ('Gap', '0.27790705699'),
#   ('Carolina Herrera', '0.272070070443'),
#   ('Ann Taylor', '0.261331967496'),
#   ('J.Crew', '0.243864250015'),
#   ('Ann Taylor Loft', '0.227243376655'),
#   ('Donna Karan', '0.217157547175'),
#   ('LOFT', '0.212304738625'),
#   ('Jill Stuart', '0.198271643259'),
#   ('Be & D', '0.19605137424')],
#  [('NARS', '1.0'),
#   ('M\xc2\xb7A\xc2\xb7C', '0.8689477452'),
#   ('Bobbi Brown', '0.839851403845'),
#   ('Stila', '0.731897473708'),
#   ('Urban Decay', '0.709269029529'),
#   ('Essie', '0.704438236785'),
#   ('Benefit', '0.622081232744'),
#   ('Lush', '0.597008320818'),
#   ('Sephora', '0.593611978751'),
#   ('philosophy', '0.586575824831')],
#  [('The Body Shop', '1.0'),
#   ('Bumble and Bumble', '0.855345831526'),
#   ('Benefit', '0.843684182332'),
#   ('Maybelline', '0.830433679068'),
#   ('Clean & Clear', '0.828312315013'),
#   ('Cover Girl', '0.827746885745'),
#   ('Bliss', '0.817793963796'),
#   ('Billabong', '0.812936452291'),
#   ('Judith Leiber', '0.805327836143'),
#   ('Apothia', '0.801560931068')],
#  [('GUESS by Marciano', '1.0'),
#   ('Max Studio', '0.791987669378'),
#   ('Creative Recreation', '0.765576304127'),
#   ('Spiegel', '0.740880990556'),
#   ('Cheap Monday', '0.726972339263'),
#   ('Faviana', '0.656912001683'),
#   ('Newport News', '0.649013390044'),
#   ('eDressMe', '0.643928814581'),
#   ('Ed Hardy', '0.638101798994'),
#   ('INC International Concepts', '0.634448291128')],
#  [('American Apparel', '1.0'),
#   ('Alloy', '0.353281809257'),
#   ('Silence & Noise', '0.347497119231'),
#   ('Acne Jeans', '0.291237761231'),
#   ('Fred Flare', '0.287467639099'),
#   ('American Eagle', '0.278864572205'),
#   ('BDG', '0.21486923669'),
#   ('House Of Harlow', '0.20854967022'),
#   ('Sally Hansen', '0.202755219007'),
#   ("Levi's", '0.197553341837')],
#  [('Michael Kors', '1.0'),
#   ('Carolina Herrera', '0.244988368348'),
#   ('MICHAEL Michael Kors', '0.219489581244'),
#   ('Coach', '0.209990397927'),
#   ('Marc Jacobs', '0.194794524711'),
#   ('Marc by Marc Jacobs', '0.187503188589'),
#   ('Hermes', '0.186849521662'),
#   ('Mulberry', '0.182693834994'),
#   ('KORS', '0.182284974643'),
#   ('Jill Stuart', '0.173196347661')],
#  [('Chlo\xc3\xa9', '1.0'),
#   ('Yves Saint Laurent', '0.34759411513'),
#   ('Marc Jacobs', '0.339702445611'),
#   ('Jimmy Choo', '0.329203427303'),
#   ('Gucci', '0.316654501026'),
#   ('Marc by Marc Jacobs', '0.212122521656'),
#   ('Clinique', '0.188761905064'),
#   ('Burberry', '0.187571716098'),
#   ('Christian Louboutin', '0.174076881175'),
#   ('Lanc\xc3\xb4me', '0.161582277663')],
#  [('J.Crew', '1.0'),
#   ('Banana Republic', '0.243864250015'),
#   ('Calvin Klein', '0.209646000356'),
#   ('Jill Stuart', '0.209262699861'),
#   ('Carolina Herrera', '0.205397382171'),
#   ('Kate Spade', '0.19641999639'),
#   ('Gap', '0.191903100387'),
#   ('Mulberry', '0.188675588745'),
#   ('Tory Burch', '0.183808799829'),
#   ('Philosophy di Alberta Ferretti', '0.177521181452')],
#  [('Rebecca Taylor', '1.0'),
#   ('Rachel Pally', '0.621968595389'),
#   ('Shoshanna', '0.620427382237'),
#   ('Twelfth St. By Cynthia Vincent', '0.580149295548'),
#   ('Ella Moss', '0.507889872985'),
#   ('T-Bags', '0.495554289964'),
#   ('Be & D', '0.480770205552'),
#   ('Botkier', '0.472933364717'),
#   ('Splendid', '0.472014703597'),
#   ('Trina Turk', '0.471118655179')],
#  [('Bottega Veneta', '1.0'),
#   ('Emilio Pucci', '0.443235097621'),
#   ('Salvatore Ferragamo', '0.430577551997'),
#   ('Botkier', '0.377780848414'),
#   ("Tod's", '0.371227518073'),
#   ('Paul Smith', '0.341062515503'),
#   ('McQ by Alexander McQueen', '0.328130004252'),
#   ('Vivienne Westwood', '0.317446419477'),
#   ('Marni', '0.304170798823'),
#   ('DSquared', '0.298009478292')],
#  [('Etro', '1.0'),
#   ('Thakoon', '0.982115766985'),
#   ('Dries Van Noten', '0.980081317038'),
#   ('Jil Sander', '0.979310832365'),
#   ('Philosophy di Alberta Ferretti', '0.975347083026'),
#   ('Derek Lam', '0.974425594145'),
#   ('Jill Stuart', '0.963102914411'),
#   ('The Row', '0.962385569104'),
#   ("L'Wren Scott", '0.958497350677'),
#   ('Doo.Ri', '0.953527544369')],
#  [('Ralph Lauren', '1.0'),
#   ('Donna Karan', '0.378631046973'),
#   ('Carolina Herrera', '0.35754047726'),
#   ('Tommy Hilfiger', '0.342468878888'),
#   ('Ralph', '0.24184153429'),
#   ('Ralph Lauren Blue Label', '0.236910051419'),
#   ('Mulberry', '0.232665195971'),
#   ('Hermes', '0.219584436314'),
#   ('Jill Stuart', '0.215117947547'),
#   ('Philosophy di Alberta Ferretti', '0.209685822341')],
#  [("L'Wren Scott", '1.0'),
#   ('Doo.Ri', '0.996043246703'),
#   ('Pierre Hardy', '0.993492304738'),
#   ('Jonathan Saunders', '0.993161130731'),
#   ('Luella', '0.991716717698'),
#   ('Lee Angel', '0.991081408165'),
#   ('Roger Vivier', '0.990451214691'),
#   ('Erickson Beamon', '0.990440676529'),
#   ('Tom Binns', '0.989472110019'),
#   ('Chris Benz', '0.988722714856')],
#  [('Donna Karan', '1.0'),
#   ('Carolina Herrera', '0.702880053719'),
#   ('Moschino', '0.590470420977'),
#   ('Sergio Rossi', '0.549006301863'),
#   ('Jil Sander', '0.54867505615'),
#   ('Jill Stuart', '0.540168152871'),
#   ('Derek Lam', '0.534510576179'),
#   ('Anna Sui', '0.529405484172'),
#   ('Philosophy di Alberta Ferretti', '0.526257461901'),
#   ('Etro', '0.517634773274')],
#  [('Jill Stuart', '1.0'),
#   ('Luella', '0.981410952242'),
#   ('Pierre Hardy', '0.977124306306'),
#   ("L'Wren Scott", '0.976100839851'),
#   ('Doo.Ri', '0.97097105541'),
#   ('Mulberry', '0.970128206924'),
#   ('Lee Angel', '0.966622307276'),
#   ('TSE', '0.965854288544'),
#   ('Jonathan Saunders', '0.964351578736'),
#   ('Etro', '0.963102914411')],
#  [('Kenneth Jay Lane', '1.0'),
#   ('Be & D', '0.712514612828'),
#   ('Eugenia Kim', '0.696824492051'),
#   ('Karen Walker', '0.663616978325'),
#   ('Katayone Adeli', '0.659719188545'),
#   ('Mayle', '0.654536878475'),
#   ('Mark Davis', '0.649810872084'),
#   ('Subversive Jewelry', '0.638559640094'),
#   ('Chris Benz', '0.619678947449'),
#   ('TSE', '0.617170728082')],
#  [('Luella', '1.0'),
#   ('TSE', '0.993002404818'),
#   ("L'Wren Scott", '0.991716717698'),
#   ('Pierre Hardy', '0.989027258113'),
#   ('Doo.Ri', '0.988202072333'),
#   ('Roger Vivier', '0.985831703828'),
#   ('Jonathan Saunders', '0.983613314509'),
#   ('Subversive Jewelry', '0.98289842992'),
#   ('Lee Angel', '0.982407496895'),
#   ('Jill Stuart', '0.981410952242')],
#  [('Stella McCartney', '1.0'),
#   ('Marni', '0.355883041742'),
#   ('McQ by Alexander McQueen', '0.283994114547'),
#   ('Vivienne Westwood', '0.255715158415'),
#   ('Donna Karan', '0.240807801203'),
#   ('Proenza Schouler', '0.222995567743'),
#   ('Alexander Mc Queen', '0.205115056566'),
#   ('Carolina Herrera', '0.202789194501'),
#   ('Jil Sander', '0.186304640957'),
#   ('Sergio Rossi', '0.178682198117')],
#  [('Vera Wang', '1.0'),
#   ('Donna Karan', '0.327052829575'),
#   ('Carolina Herrera', '0.287423755287'),
#   ('Versace', '0.219255703983'),
#   ('Oscar de la Renta', '0.186825213963'),
#   ('Kenneth Cole', '0.177076165052'),
#   ('Max Studio', '0.17682902045'),
#   ('McQ by Alexander McQueen', '0.175986790486'),
#   ('DKNY', '0.171748172271'),
#   ('Jill Stuart', '0.169596925974')],
#  [('Philosophy di Alberta Ferretti', '1.0'),
#   ('Etro', '0.975347083026'),
#   ('Derek Lam', '0.963932301654'),
#   ('Jil Sander', '0.962778729362'),
#   ('Thakoon', '0.962722759096'),
#   ('Sergio Rossi', '0.943085768199'),
#   ('Jill Stuart', '0.942155009752'),
#   ('Dries Van Noten', '0.939152210781'),
#   ('The Row', '0.931515664273'),
#   ('Mulberry', '0.930185725616')],
#  [('Karen Walker', '1.0'),
#   ('Fallon', '0.951658302527'),
#   ('Jonathan Saunders', '0.951223054816'),
#   ('Chris Benz', '0.95030787569'),
#   ('Tom Binns', '0.947347044031'),
#   ('Pierre Hardy', '0.946158067764'),
#   ('Lee Angel', '0.945158603939'),
#   ('Doo.Ri', '0.944429870512'),
#   ('Erickson Beamon', '0.943197399623'),
#   ('Roger Vivier', '0.942004685515')],
#  [('DKNY', '1.0'),
#   ('Donna Karan', '0.507495132218'),
#   ('Carolina Herrera', '0.227730422028'),
#   ('Tommy Hilfiger', '0.22674933459'),
#   ('Calvin Klein', '0.226007641678'),
#   ('Ralph Lauren', '0.204334682683'),
#   ('Kenneth Cole', '0.202648084508'),
#   ('Gap', '0.196729980828'),
#   ('Banana Republic', '0.194270597073'),
#   ('Puma', '0.177466643852')],
#  [('Lanvin', '1.0'),
#   ('Marni', '0.445511283776'),
#   ('Guerlain', '0.324008021477'),
#   ('Proenza Schouler', '0.319685834278'),
#   ('Paul & Joe', '0.283202181743'),
#   ('Hermes', '0.268680548808'),
#   ('Kenneth Jay Lane', '0.258086194927'),
#   ('Rick Owens', '0.254500558005'),
#   ('Marchesa', '0.252793008283'),
#   ('Helmut Lang', '0.2482852945')],
#  [('Gap', '1.0'),
#   ('Banana Republic', '0.27790705699'),
#   ('Carolina Herrera', '0.203002644183'),
#   ('Old Navy', '0.197912930749'),
#   ('Coach', '0.197861268596'),
#   ('DKNY', '0.196729980828'),
#   ('New York & Co.', '0.192129642831'),
#   ('J.Crew', '0.191903100387'),
#   ('Ralph Lauren', '0.182416921956'),
#   ('Donna Karan', '0.174817582924')],
#  [('Thakoon', '1.0'),
#   ('The Row', '0.984881739095'),
#   ('Dries Van Noten', '0.983097947998'),
#   ('Etro', '0.982115766985'),
#   ('A.P.C.', '0.97336485781'),
#   ('Derek Lam', '0.972343905608'),
#   ('Erickson Beamon', '0.965519222939'),
#   ('Doo.Ri', '0.964652010422'),
#   ('Jil Sander', '0.964436131225'),
#   ("L'Wren Scott", '0.963369399338')],
#  [('Subversive Jewelry', '1.0'),
#   ('Mark Davis', '0.996344581226'),
#   ('TSE', '0.994707437837'),
#   ('Katayone Adeli', '0.99287723354'),
#   ('Mayle', '0.99199566244'),
#   ('Chris Benz', '0.986153101696'),
#   ('Jonathan Saunders', '0.984669424225'),
#   ('Luella', '0.98289842992'),
#   ('Lee Angel', '0.98248266219'),
#   ('Roger Vivier', '0.982045439839')],
#  [('Pierre Hardy', '1.0'),
#   ('Jonathan Saunders', '0.995527823303'),
#   ('Doo.Ri', '0.994095188906'),
#   ("L'Wren Scott", '0.993492304738'),
#   ('Roger Vivier', '0.99162984553'),
#   ('Lee Angel', '0.991410742657'),
#   ('Fallon', '0.991327430994'),
#   ('Chris Benz', '0.991064173004'),
#   ('Luella', '0.989027258113'),
#   ('Tom Binns', '0.987738611375')],
#  [('Balenciaga', '1.0'),
#   ('Proenza Schouler', '0.262745965846'),
#   ('Bottega Veneta', '0.197658159848'),
#   ('Mulberry', '0.186635405972'),
#   ('Anna Sui', '0.184889674635'),
#   ('Marni', '0.182973627038'),
#   ('McQ by Alexander McQueen', '0.180759659758'),
#   ('Alexander McQueen', '0.161543967263'),
#   ('Carolina Herrera', '0.158953564806'),
#   ('Brian Atwood', '0.158839212968')],
#  [('Valentino', '1.0'),
#   ('Oscar de la Renta', '0.250258232847'),
#   ('Marchesa', '0.23928541774'),
#   ('Max Mara', '0.200416121642'),
#   ('Clinique', '0.199110721524'),
#   ('Salvatore Ferragamo', '0.190858036318'),
#   ('Swarovski', '0.188691299886'),
#   ('La Femme', '0.182906866292'),
#   ('Elle', '0.178104083556'),
#   ('Notte by Marchesa', '0.177462222874')],
#  [('Calvin Klein', '1.0'),
#   ('Carolina Herrera', '0.312956322231'),
#   ('Donna Karan', '0.280845186328'),
#   ('DKNY', '0.226007641678'),
#   ('Jill Stuart', '0.213142510664'),
#   ('Mulberry', '0.212314042069'),
#   ('J.Crew', '0.209646000356'),
#   ('Jil Sander', '0.204629812849'),
#   ('Hermes', '0.197942944953'),
#   ('Ralph Lauren', '0.196235832275')],
#  [('Givenchy', '1.0'),
#   ('Guerlain', '0.239146449896'),
#   ('Hermes', '0.230200283793'),
#   ('McQ by Alexander McQueen', '0.216238942679'),
#   ('Mulberry', '0.21505015195'),
#   ('Emporio Armani', '0.212585309725'),
#   ('Carolina Herrera', '0.190947766112'),
#   ('Oscar de la Renta', '0.189004264953'),
#   ('Donna Karan', '0.187914717724'),
#   ('Charlotte Olympia', '0.187887735674')],
#  [('Jil Sander', '1.0'),
#   ('Derek Lam', '0.983369803881'),
#   ('Dries Van Noten', '0.981561402575'),
#   ('Etro', '0.979310832365'),
#   ('Thakoon', '0.964436131225'),
#   ('Philosophy di Alberta Ferretti', '0.962778729362'),
#   ('The Row', '0.942150163449'),
#   ('Mulberry', '0.940906171432'),
#   ('Jill Stuart', '0.940817667171'),
#   ('Peter Som', '0.930609359512')],
#  [('Sergio Rossi', '1.0'),
#   ('Etro', '0.945168758592'),
#   ('Philosophy di Alberta Ferretti', '0.943085768199'),
#   ('Thakoon', '0.923367054119'),
#   ('Jil Sander', '0.920740457187'),
#   ('Jill Stuart', '0.916357728612'),
#   ('The Row', '0.915813468572'),
#   ('Derek Lam', '0.915702425101'),
#   ('Dries Van Noten', '0.907383000027'),
#   ("L'Wren Scott", '0.897448442924')],
#  [('Tom Ford', '1.0'),
#   ('Oliver Peoples', '0.317509476846'),
#   ('Brian Atwood', '0.286708313421'),
#   ('Halston', '0.270383934632'),
#   ('Spanx', '0.248362857633'),
#   ('Longchamp', '0.245633669843'),
#   ('Eugenia Kim', '0.24301112023'),
#   ('Toms', '0.240260948068'),
#   ('Sergio Rossi', '0.237565168422'),
#   ('Hermes', '0.234162922161')],
#  [('Fallon', '1.0'),
#   ('Jonathan Saunders', '0.997053295396'),
#   ('Chris Benz', '0.995907521537'),
#   ('Lee Angel', '0.99479176873'),
#   ('Tom Binns', '0.993396259337'),
#   ('Doo.Ri', '0.991807750949'),
#   ('Erickson Beamon', '0.991453629324'),
#   ('Pierre Hardy', '0.991327430994'),
#   ("L'Wren Scott", '0.984510454804'),
#   ('Mark Davis', '0.984467767455')],
#  [('Mulberry', '1.0'),
#   ('Jill Stuart', '0.970128206924'),
#   ('Etro', '0.947595672496'),
#   ('Luella', '0.94348631971'),
#   ('Pierre Hardy', '0.941418561862'),
#   ('Jil Sander', '0.940906171432'),
#   ('Anya Hindmarch', '0.935561215514'),
#   ("L'Wren Scott", '0.930492276137'),
#   ('Philosophy di Alberta Ferretti', '0.930185725616'),
#   ('Roger Vivier', '0.927870773016')],
#  [('Anna Sui', '1.0'),
#   ('Moschino', '0.690484177656'),
#   ('Be & D', '0.623330256855'),
#   ('Mulberry', '0.611766432727'),
#   ('Luella', '0.610456497879'),
#   ('Jill Stuart', '0.606737695352'),
#   ('Mayle', '0.588840168552'),
#   ('Peter Som', '0.58847107034'),
#   ('TSE', '0.584238567758'),
#   ('Subversive Jewelry', '0.578915210377')],
#  [('Brian Atwood', '1.0'),
#   ('Anya Hindmarch', '0.741771182246'),
#   ('Karen Walker', '0.721976337214'),
#   ('A.P.C.', '0.677861631261'),
#   ('Roger Vivier', '0.675157938428'),
#   ('Thakoon', '0.674650857205'),
#   ('The Row', '0.672980917277'),
#   ('Erickson Beamon', '0.672527357828'),
#   ('Tom Binns', '0.669480243841'),
#   ('Dries Van Noten', '0.667842651921')],
#  [('Lee Angel', '1.0'),
#   ('Jonathan Saunders', '0.996328314986'),
#   ('Doo.Ri', '0.995669345777'),
#   ('Fallon', '0.99479176873'),
#   ('Tom Binns', '0.994504779134'),
#   ('Erickson Beamon', '0.994310045891'),
#   ('Chris Benz', '0.994064197304'),
#   ('Pierre Hardy', '0.991410742657'),
#   ("L'Wren Scott", '0.991081408165'),
#   ('Mark Davis', '0.983511063012')],
#  [('Marni', '1.0'),
#   ('Proenza Schouler', '0.694813755223'),
#   ('Be & D', '0.542361385678'),
#   ('Dries Van Noten', '0.528400698144'),
#   ('Helmut Lang', '0.494058694451'),
#   ('Loeffler Randall', '0.490653838928'),
#   ('Derek Lam', '0.487032917301'),
#   ('Thakoon', '0.486870308872'),
#   ('Luella', '0.479568747982'),
#   ('The Row', '0.476239128216')],
#  [('Peter Som', '1.0'),
#   ("L'Wren Scott", '0.981298541312'),
#   ('Roger Vivier', '0.980880609741'),
#   ('Pierre Hardy', '0.979463377273'),
#   ('Luella', '0.978684087094'),
#   ('Doo.Ri', '0.978651833319'),
#   ('Jonathan Saunders', '0.977048788912'),
#   ('TSE', '0.974395486285'),
#   ('Chris Benz', '0.973823169171'),
#   ('Subversive Jewelry', '0.966834715339')],
#  [('Roger Vivier', '1.0'),
#   ('Pierre Hardy', '0.99162984553'),
#   ('Jonathan Saunders', '0.990759887257'),
#   ("L'Wren Scott", '0.990451214691'),
#   ('Chris Benz', '0.989192489998'),
#   ('TSE', '0.988760335873'),
#   ('Doo.Ri', '0.988614220036'),
#   ('Luella', '0.985831703828'),
#   ('Fallon', '0.983221037567'),
#   ('Lee Angel', '0.982679460796')],
#  [('TSE', '1.0'),
#   ('Subversive Jewelry', '0.994707437837'),
#   ('Luella', '0.993002404818'),
#   ('Roger Vivier', '0.988760335873'),
#   ("L'Wren Scott", '0.988214864347'),
#   ('Mark Davis', '0.988191018534'),
#   ('Pierre Hardy', '0.985422860348'),
#   ('Jonathan Saunders', '0.985156991792'),
#   ('Doo.Ri', '0.984727163533'),
#   ('Chris Benz', '0.984618025809')],
#  [('Doo.Ri', '1.0'),
#   ('Jonathan Saunders', '0.996513561954'),
#   ("L'Wren Scott", '0.996043246703'),
#   ('Lee Angel', '0.995669345777'),
#   ('Erickson Beamon', '0.995473350132'),
#   ('Tom Binns', '0.994564379926'),
#   ('Chris Benz', '0.994318928273'),
#   ('Pierre Hardy', '0.994095188906'),
#   ('Fallon', '0.991807750949'),
#   ('Roger Vivier', '0.988614220036')],
#  [('Katayone Adeli', '1.0'),
#   ('Mayle', '0.998142324956'),
#   ('Mark Davis', '0.996980271992'),
#   ('Subversive Jewelry', '0.99287723354'),
#   ('Chris Benz', '0.986208880075'),
#   ('TSE', '0.98358655248'),
#   ('Jonathan Saunders', '0.98122154032'),
#   ('Fallon', '0.98038436507'),
#   ('Roger Vivier', '0.978310442479'),
#   ('Lee Angel', '0.974492631191')],
#  [('Tom Binns', '1.0'),
#   ('Erickson Beamon', '0.997835999275'),
#   ('Jonathan Saunders', '0.994833647075'),
#   ('Doo.Ri', '0.994564379926'),
#   ('Lee Angel', '0.994504779134'),
#   ('Chris Benz', '0.993448131235'),
#   ('Fallon', '0.993396259337'),
#   ("L'Wren Scott", '0.989472110019'),
#   ('Pierre Hardy', '0.987738611375'),
#   ('Roger Vivier', '0.982170344684')],
#  [('Halston', '1.0'),
#   ('Eugenia Kim', '0.745062761132'),
#   ('Karen Walker', '0.60834572482'),
#   ('Sue Wong', '0.595831940918'),
#   ('The Row', '0.559343623689'),
#   ('Tom Binns', '0.557601583593'),
#   ('Fallon', '0.556241009035'),
#   ('Erickson Beamon', '0.555546997075'),
#   ('Kenneth Jay Lane', '0.54820785164'),
#   ('Jonathan Saunders', '0.547744045651')],
#  [('Chris Benz', '1.0'),
#   ('Jonathan Saunders', '0.997540381513'),
#   ('Fallon', '0.995907521537'),
#   ('Doo.Ri', '0.994318928273'),
#   ('Lee Angel', '0.994064197304'),
#   ('Tom Binns', '0.993448131235'),
#   ('Erickson Beamon', '0.992435412938'),
#   ('Pierre Hardy', '0.991064173004'),
#   ('Mark Davis', '0.990427969565'),
#   ('Roger Vivier', '0.989192489998')],
#  [('Jonathan Saunders', '1.0'),
#   ('Chris Benz', '0.997540381513'),
#   ('Fallon', '0.997053295396'),
#   ('Doo.Ri', '0.996513561954'),
#   ('Lee Angel', '0.996328314986'),
#   ('Pierre Hardy', '0.995527823303'),
#   ('Tom Binns', '0.994833647075'),
#   ('Erickson Beamon', '0.994322153413'),
#   ("L'Wren Scott", '0.993161130731'),
#   ('Roger Vivier', '0.990759887257')],
#  [('The Row', '1.0'),
#   ('Thakoon', '0.984881739095'),
#   ("L'Wren Scott", '0.975443643204'),
#   ('Doo.Ri', '0.974480675767'),
#   ('A.P.C.', '0.973762661954'),
#   ('Erickson Beamon', '0.973414612702'),
#   ('Tom Binns', '0.973065277048'),
#   ('Dries Van Noten', '0.968347211562'),
#   ('Pierre Hardy', '0.968148653466'),
#   ('Lee Angel', '0.965715008433')],
#  [('Mark Davis', '1.0'),
#   ('Katayone Adeli', '0.996980271992'),
#   ('Subversive Jewelry', '0.996344581226'),
#   ('Mayle', '0.994184462261'),
#   ('Chris Benz', '0.990427969565'),
#   ('TSE', '0.988191018534'),
#   ('Jonathan Saunders', '0.986188313288'),
#   ('Fallon', '0.984467767455'),
#   ('Lee Angel', '0.983511063012'),
#   ('Roger Vivier', '0.979763021975')],
#  [('Anya Hindmarch', '1.0'),
#   ('Pierre Hardy', '0.979046069754'),
#   ('Doo.Ri', '0.97893935064'),
#   ('Jonathan Saunders', '0.975763277246'),
#   ("L'Wren Scott", '0.975042555458'),
#   ('A.P.C.', '0.974945933017'),
#   ('Erickson Beamon', '0.974861232966'),
#   ('Roger Vivier', '0.973967273381'),
#   ('Fallon', '0.97270436964'),
#   ('Chris Benz', '0.971590621415')],
#  [('3.1 Phillip Lim', '1.0'),
#   ('Marni', '0.326882172942'),
#   ('Acne Jeans', '0.269076108372'),
#   ('Proenza Schouler', '0.260615066569'),
#   ('Derek Lam', '0.257852312235'),
#   ('Moncler', '0.255598435379'),
#   ('Rag and Bone', '0.252892930981'),
#   ('Helmut Lang', '0.249882621622'),
#   ('Black Halo', '0.247772642732'),
#   ('Isabel Marant', '0.235503948572')],
#  [('Alexander McQueen', '1.0'),
#   ('McQ by Alexander McQueen', '0.375687883386'),
#   ('Brian Atwood', '0.186524260299'),
#   ('AllSaints', '0.181221828196'),
#   ('Halston', '0.1792191652'),
#   ('Guerlain', '0.166071966265'),
#   ('Charlotte Olympia', '0.165688660891'),
#   ('Balenciaga', '0.161543967263'),
#   ('philosophy', '0.160522382527'),
#   ('Jean Paul Gaultier', '0.157866288121')],
#  [('Cartier', '1.0'),
#   ('Bally', '0.992773360184'),
#   ('Loewe', '0.991434835909'),
#   ('Van Cleef & Arpels', '0.99125194696'),
#   ('Karl Lagerfeld', '0.989685464985'),
#   ('Pucci', '0.989284051766'),
#   ('Ferragamo', '0.989221293673'),
#   ('Gianfranco Ferre', '0.989092495326'),
#   ('John Galliano', '0.989021983549'),
#   ('Issey Miyake', '0.986918224601')],
#  [('Celine', '1.0'),
#   ('Comme des Garcons', '0.977897613972'),
#   ('Ann Demeulemeester', '0.971899089551'),
#   ('Acne', '0.971262763134'),
#   ('Maison Martin Margiela', '0.96966821592'),
#   ('Etoile Isabel Marant', '0.967394336566'),
#   ('Alaia', '0.966036171233'),
#   ('Carven', '0.96585798606'),
#   ('Christopher Kane', '0.964856679629'),
#   ('Reed Krakoff', '0.964763214254')],
#  [('Dolce & Gabbana', '1.0'),
#   ('Versace', '0.432012273934'),
#   ('D&G', '0.331601030307'),
#   ('Oscar de la Renta', '0.269094925649'),
#   ('Emporio Armani', '0.197340218376'),
#   ('Vivienne Westwood', '0.194783452828'),
#   ('Ed Hardy', '0.173522815205'),
#   ('DSquared', '0.170291355812'),
#   ('Tommy Hilfiger', '0.165360809737'),
#   ('Roberto Cavalli', '0.159095407643')],
#  [('Missoni', '1.0'),
#   ('Tadashi Shoji', '0.478380506152'),
#   ('Emilio Pucci', '0.474422942637'),
#   ('Fiorentini+Baker', '0.459591315856'),
#   ('Aquatalia by Marvin K', '0.438650446795'),
#   ('Vivienne Westwood', '0.437458692201'),
#   ('M Missoni', '0.428199718277'),
#   ('Scala', '0.41835643006'),
#   ('Mackage', '0.410589388333'),
#   ('DSquared', '0.376367352825')],
#  [('Moncler', '1.0'),
#   ('Mackage', '0.590867027408'),
#   ('Rag and Bone', '0.572160829317'),
#   ('Creative Recreation', '0.565894483472'),
#   ('Loeffler Randall', '0.554682937646'),
#   ('Mike & Chris', '0.542143550849'),
#   ('Vince', '0.499831365348'),
#   ('Cheap Monday', '0.464897029061'),
#   ('Current/Elliott', '0.437289781739'),
#   ('Ash', '0.431054018111')],
#  [('Isabel Marant', '1.0'),
#   ('Wildfox Couture', '0.887081489595'),
#   ('Jo Malone', '0.886904408861'),
#   ('Charlotte Olympia', '0.865297771053'),
#   ('Maison Martin Margiela', '0.853906797374'),
#   ('Dr. Martens', '0.845299961271'),
#   ('Oribe', '0.84383008169'),
#   ('Faliero Sarti', '0.838255397533'),
#   ('Acne', '0.837091010933'),
#   ('CLEAN', '0.835842041149')],
#  [('A.P.C.', '1.0'),
#   ('Erickson Beamon', '0.976601305166'),
#   ('Doo.Ri', '0.976371831409'),
#   ('Tom Binns', '0.974980371716'),
#   ('Anya Hindmarch', '0.974945933017'),
#   ('The Row', '0.973762661954'),
#   ('Thakoon', '0.97336485781'),
#   ('Fallon', '0.973050168046'),
#   ('Pierre Hardy', '0.971329089692'),
#   ('Jonathan Saunders', '0.971047279805')],
#  [('Tommy Hilfiger', '1.0'),
#   ('G by Guess', '0.716711756719'),
#   ('Lacoste', '0.679413764711'),
#   ('Liz Claiborne', '0.67160636169'),
#   ('Emporio Armani', '0.637193626711'),
#   ("Levi's", '0.607903798223'),
#   ('Bed Bath & Beyond', '0.56309839532'),
#   ('Versace', '0.545102049888'),
#   ('Oscar de la Renta', '0.543370579328'),
#   ('Rampage', '0.542525483674')],
#  [('Max Mara', '1.0'),
#   ('Monique Lhuillier', '0.851526542723'),
#   ('Nina Ricci', '0.841191492219'),
#   ('Narciso Rodriguez', '0.832434719875'),
#   ('Isaac Mizrahi', '0.831136117833'),
#   ('Rodarte', '0.82671353794'),
#   ('Christian Lacroix', '0.825787276218'),
#   ('Viktor & Rolf', '0.821639251481'),
#   ('Emanuel Ungaro', '0.818655301848'),
#   ('Jean Paul Gaultier', '0.812378015644')],
#  [('Roberto Cavalli', '1.0'),
#   ('Just Cavalli', '0.618311677662'),
#   ('Versace', '0.376704204748'),
#   ('Oscar de la Renta', '0.31526533838'),
#   ('Rock & Republic', '0.282087915426'),
#   ('GUESS by Marciano', '0.277307011109'),
#   ('Emporio Armani', '0.233829989968'),
#   ('Robert Rodriguez', '0.197853088662'),
#   ('Vivienne Westwood', '0.191973811534'),
#   ('Puma', '0.165178437012')],
#  [('Zac Posen', '1.0'),
#   ('Blumarine', '0.99175066805'),
#   ('Giambattista Valli', '0.988092248395'),
#   ('Alberta Ferretti', '0.98660421313'),
#   ('Matthew Williamson', '0.982348500983'),
#   ('Viktor & Rolf', '0.971475581802'),
#   ('Narciso Rodriguez', '0.96790316953'),
#   ('Nina Ricci', '0.961994708407'),
#   ('Rodarte', '0.956758171635'),
#   ('Giorgio Armani', '0.947721288751')],
#  [('Giambattista Valli', '1.0'),
#   ('Alberta Ferretti', '0.996299121081'),
#   ('Blumarine', '0.993484341287'),
#   ('Zac Posen', '0.988092248395'),
#   ('Viktor & Rolf', '0.987126296919'),
#   ('Narciso Rodriguez', '0.983021631176'),
#   ('Rodarte', '0.981799884478'),
#   ('Nina Ricci', '0.975863246302'),
#   ('Matthew Williamson', '0.968493845744'),
#   ('Giorgio Armani', '0.946947800948')],
#  [('Lauren Ralph Lauren', '1.0'),
#   ('Polo Ralph Lauren', '0.725539057345'),
#   ('Kenneth Cole', '0.551263024547'),
#   ('Tommy Hilfiger', '0.461287250173'),
#   ('Brooks Brothers', '0.435410301674'),
#   ('Lacoste', '0.434694042743'),
#   ("Levi's", '0.430831498691'),
#   ('Emporio Armani', '0.415132942101'),
#   ('Spiegel', '0.409630974729'),
#   ('Hugo Boss', '0.406532079357')],
#  [('Polo Ralph Lauren', '1.0'),
#   ('Lauren Ralph Lauren', '0.725539057345'),
#   ("Levi's", '0.353263567688'),
#   ('Tommy Hilfiger', '0.333428092694'),
#   ('Emporio Armani', '0.312600640836'),
#   ('Ann Taylor Loft', '0.281417241944'),
#   ('Puma', '0.27794317869'),
#   ('Lacoste', '0.269677728176'),
#   ('Salvatore Ferragamo', '0.266389006792'),
#   ('adidas', '0.250643344688')],
#  [('Theory', '1.0'),
#   ('Vince', '0.47239533631'),
#   ('Elie Tahari', '0.389353830101'),
#   ('Max Studio', '0.377088189817'),
#   ('James Perse', '0.366703221478'),
#   ('Splendid', '0.360816494793'),
#   ('Ella Moss', '0.34800927055'),
#   ('Laundry by Shelli Segal', '0.339665346361'),
#   ('Tahari', '0.319233430205'),
#   ('Black Halo', '0.313242537803')],
#  [('Ralph Lauren Black Label', '1.0'),
#   ('RLX Ralph Lauren', '0.996206487571'),
#   ('Ralph Lauren Home', '0.994547686161'),
#   ('Ralph Lauren Fragrance', '0.993294110538'),
#   ('Denim & Supply Ralph Lauren', '0.992303806611'),
#   ('Ralph Lauren Blue Label', '0.98916981031'),
#   ('Ralph', '0.981392831821'),
#   ('Polo Jeans', '0.979889237741'),
#   ('Hugo', '0.979091990393'),
#   ('CK Calvin Klein', '0.978710467591')],
#  [('Ralph Lauren Blue Label', '1.0'),
#   ('Ralph Lauren Black Label', '0.98916981031'),
#   ('Ralph', '0.988301715939'),
#   ('RLX Ralph Lauren', '0.98699119552'),
#   ('Ralph Lauren Fragrance', '0.982218291097'),
#   ('Ralph Lauren Home', '0.978323007638'),
#   ('Denim & Supply Ralph Lauren', '0.97216506114'),
#   ('CK Calvin Klein', '0.952270406274'),
#   ('Boss Black', '0.950404143429'),
#   ('Calvin Klein Jeans', '0.947567731368')],
#  [('Alexander Wang', '1.0'),
#   ('Helmut Lang', '0.235052218862'),
#   ('Rick Owens', '0.209752049315'),
#   ('Alexander Mc Queen', '0.20814005749'),
#   ('McQ by Alexander McQueen', '0.203131889714'),
#   ('Proenza Schouler', '0.193014195176'),
#   ('A.P.C.', '0.192710059489'),
#   ('Isabel Marant', '0.188520838607'),
#   ('Anna Sui', '0.181731456345'),
#   ('Topshop', '0.180677928063')],
#  [('Liz Claiborne', '1.0'),
#   ('Bed Bath & Beyond', '0.944106476315'),
#   ('Eddie Bauer', '0.92154925242'),
#   ('Apt. 9', '0.904990907998'),
#   ('AK Anne Klein', '0.904869882707'),
#   ('Jones New York', '0.896362374558'),
#   ('Talbots', '0.875045872552'),
#   ("Chico's", '0.867724783577'),
#   ('Kenneth Cole Reaction', '0.8567375574'),
#   ('Rampage', '0.841787070052')],
#  [('Badgley Mischka', '1.0'),
#   ('Oscar de la Renta', '0.511465023862'),
#   ('Elie Tahari', '0.495426559676'),
#   ('Vivienne Westwood', '0.477988045877'),
#   ('Notte by Marchesa', '0.477168723022'),
#   ('Marchesa', '0.452710938119'),
#   ('Tahari', '0.441188279426'),
#   ('Tadashi Shoji', '0.407522977059'),
#   ('Beach Sexy', '0.390586550054'),
#   ('Proenza Schouler', '0.388858347671')],
#  [('Blumarine', '1.0'),
#   ('Giambattista Valli', '0.993484341287'),
#   ('Alberta Ferretti', '0.991899191664'),
#   ('Zac Posen', '0.99175066805'),
#   ('Narciso Rodriguez', '0.983155083745'),
#   ('Viktor & Rolf', '0.981985280578'),
#   ('Nina Ricci', '0.976964090218'),
#   ('Rodarte', '0.974332874589'),
#   ('Matthew Williamson', '0.965896092889'),
#   ('Giorgio Armani', '0.959803492533')],
#  [('Christian Lacroix', '1.0'),
#   ('Jean Paul Gaultier', '0.98769655114'),
#   ('Nina Ricci', '0.9551566776'),
#   ('Narciso Rodriguez', '0.949084479964'),
#   ('Rodarte', '0.937720060755'),
#   ('Emanuel Ungaro', '0.936447354141'),
#   ('Viktor & Rolf', '0.936329462199'),
#   ('Monique Lhuillier', '0.935031060794'),
#   ('Isaac Mizrahi', '0.934480038908'),
#   ('Blumarine', '0.92828167318')],
#  [('Alberta Ferretti', '1.0'),
#   ('Giambattista Valli', '0.996299121081'),
#   ('Blumarine', '0.991899191664'),
#   ('Viktor & Rolf', '0.988464821884'),
#   ('Zac Posen', '0.98660421313'),
#   ('Narciso Rodriguez', '0.983937148327'),
#   ('Rodarte', '0.980164850319'),
#   ('Nina Ricci', '0.978648960943'),
#   ('Matthew Williamson', '0.964515178255'),
# ...
#   ('A.L.C.', '0.990246526329'),
#   ('IRO', '0.989974822645'),
#   ('Maje', '0.989129031968'),
#   ('Etoile Isabel Marant', '0.98870919108'),
#   ('Carven', '0.988556629274'),
#   ('Band Of Outsiders', '0.988225480992'),
#   ('Boy By Band Of Outsiders', '0.988107695098'),
#   ('Chloe Sevigny for Opening Ceremony', '0.98519065635'),
#   ('Acne', '0.985140584026')],
#  [('Anna Sheffield 88 Collection', '1.0'),
#   ('Reclaimed Vintage', '0.999671220105'),
#   ('Minneola', '0.999657102891'),
#   ('Xti', '0.999627067553'),
#   ('Elizabeth Locke', '0.999623758378'),
#   ('Chalayan', '0.999620145849'),
#   ('Hoya', '0.999618160437'),
#   ('Rota', '0.999614931606'),
#   ('Kona', '0.999609440324'),
#   ('Erich Ginder', '0.999608423996')],
#  [('Boy', '1.0'),
#   ('Dieppa Restrepo', '0.997956787365'),
#   ('F-Troupe', '0.997461254597'),
#   ('B Store', '0.996880884805'),
#   ('Humanoid', '0.996864507087'),
#   ('K. Jacques', '0.996842390942'),
#   ('Rogan', '0.996835954302'),
#   ('Hope', '0.996772801025'),
#   ('N.D.C. Made By Hand', '0.996741649197'),
#   ('Built by Wendy', '0.996554364484')],
#  [('Aesop', '1.0'),
#   ('Amore Pacific', '0.998572047644'),
#   ('Ann Sofie Back', '0.998444078056'),
#   ('Antipodium', '0.998435507836'),
#   ('Aesa', '0.998242273918'),
#   ('Josie', '0.998110935924'),
#   ('Yardley London', '0.998082746225'),
#   ('Annette Ferdinandsen', '0.998061648854'),
#   ('Alexis Mabille', '0.998058205492'),
#   ('Acqua di Parma', '0.998056301879')],
#  [('Anglomania', '1.0'),
#   ('Mauro Grifoni', '0.999101158361'),
#   ('Royal Copenhagen', '0.998984081293'),
#   ('Sharon Wauchob', '0.998981209198'),
#   ('Costello Tagliapietra', '0.998975353528'),
#   ('Gunex', '0.998926988626'),
#   ('Daslu', '0.99891989518'),
#   ('Padma', '0.99890495561'),
#   ('Da-Nang', '0.998903340318'),
#   ('Jeanine Payer', '0.998900223822')],
#  [('Lucifer Vir Honestus', '1.0'),
#   ('Kotur', '0.998594279344'),
#   ('Brian Danielle', '0.998087973839'),
#   ('Jay Ahr', '0.998055762861'),
#   ('Moyna', '0.998032641103'),
#   ('Aminaka Wilmont', '0.998031868137'),
#   ('Miguel Ases', '0.997996939769'),
#   ('Charm & Chain', '0.997956856484'),
#   ('Alex Monroe', '0.997912789192'),
#   ('Cathy Waterman', '0.997882947341')],
#  [('Antipodium', '1.0'),
#   ('Ann Sofie Back', '0.999024390825'),
#   ('Aesa', '0.998976995221'),
#   ('Annette Ferdinandsen', '0.998618312599'),
#   ('Ariel Gordon', '0.998610071459'),
#   ('Assad Mounser', '0.998567568913'),
#   ('Aspesi', '0.998495016012'),
#   ('Gar-De', '0.998459100633'),
#   ('Aesop', '0.998435507836'),
#   ('Alyssa Norton', '0.998432775742')],
#  [('Rodolphe Menudier', '1.0'),
#   ('The Old Curiosity Shop', '0.999316751122'),
#   ('Alberto Fasciani', '0.999299859423'),
#   ('Kokon To Zai', '0.99929650095'),
#   ('Minimum', '0.999240105219'),
#   ('ICB', '0.999238752003'),
#   ('Sofia Tartufoli', '0.999232197257'),
#   ('Emanuela Passeri', '0.999225000777'),
#   ('Petar Petrov', '0.999197794856'),
#   ('Antonio Fusco', '0.999197480131')],
#  [('Epice', '1.0'),
#   ('Bea Yuk Mui', '0.999092327499'),
#   ('Carol Marie', '0.999056102216'),
#   ('Sykes', '0.99903563921'),
#   ('James Long', '0.999019743671'),
#   ('Quelques Fleurs', '0.99901283106'),
#   ('Neem Aura', '0.999006831023'),
#   ('Emma Hope', '0.998992120414'),
#   ('Saskia Diez', '0.998985896607'),
#   ('Renaud Pellegrino', '0.998980518389')],
#  [('N.D.C. Made By Hand', '1.0'),
#   ('Dieppa Restrepo', '0.997606372537'),
#   ('K. Jacques', '0.997593742374'),
#   ('Rogan', '0.997572730126'),
#   ('Nicholas K', '0.997123857974'),
#   ('Under.Ligne', '0.996926489437'),
#   ('B Store', '0.996919921666'),
#   ('Kai-aakmann', '0.996908156683'),
#   ('Drkshdw', '0.996885862948'),
#   ('Built by Wendy', '0.996802467187')],
#  [('Bird', '1.0'),
#   ('Madison Harding', '0.998365368963'),
#   ('Falke', '0.998332474138'),
#   ('Candela', '0.998280476788'),
#   ('Society For Rational Dress', '0.998261717037'),
#   ('The Lake & Stars', '0.9981897944'),
#   ('Wayne', '0.998180672898'),
#   ('Candela NYC', '0.99816070023'),
#   ('Lee Angel Jewelry', '0.998152895394'),
#   ('A Peace Treaty', '0.998092221395')],
#  [('Marissa Collections', '1.0'),
#   ('Toujours Moi', '0.999556135313'),
#   ('Mischen', '0.999513739212'),
#   ('Le Magnifique', '0.999487412714'),
#   ('Made in Heaven', '0.999442126348'),
#   ('Ladies of the Canyon', '0.999440393934'),
#   ('Sophyto Organics', '0.999431924705'),
#   ('Jefferies Socks', '0.999425639444'),
#   ('Tracy Matthews', '0.999417415729'),
#   ('Fifi Chachnil', '0.999399848689')],
#  [('A.L.C.', '1.0'),
#   ('IRO', '0.996547047901'),
#   ('Maje', '0.994558250684'),
#   ('Etoile Isabel Marant', '0.99261684409'),
#   ('Sandro', '0.992572274552'),
#   ('Boy By Band Of Outsiders', '0.992488504992'),
#   ('Carven', '0.992415167234'),
#   ("L'Agence", '0.990702398315'),
#   ('Rachel Comey', '0.990246526329'),
#   ('Dannijo', '0.990239173566')],
#  [('Emilio Pucci', '1.0'),
#   ('Paul Smith', '0.844449896446'),
#   ('M Missoni', '0.771554378806'),
#   ('DSquared', '0.747982049568'),
#   ('Catherine Malandrino', '0.745795454186'),
#   ('Salvatore Ferragamo', '0.728175527895'),
#   ('Carmen Marc Valvo', '0.716619742915'),
#   ('Vivienne Westwood', '0.705449375805'),
#   ('Alexander Mc Queen', '0.688435233502'),
#   ("Tod's", '0.673318127877')],
#  [('Rebecca Norman', '1.0'),
#   ('Bird Handbags', '0.999427233818'),
#   ('Barbara Biffoli', '0.999391061454'),
#   ('Glorinha Paranagua', '0.999380040751'),
#   ('Schott Zwiesel', '0.999361673677'),
#   ('De Couture', '0.999358942927'),
#   ('Kimiko Beauty', '0.999354562224'),
#   ('Denby', '0.999342958839'),
#   ('Parfum de Rosine', '0.999329080845'),
#   ('Ten Strawberry Street', '0.999314608553')],
#  [('PH Advantage', '1.0'),
#   ('Henriksdal', '0.999789154172'),
#   ('Bobbi Blu', '0.999787846692'),
#   ('Lemon', '0.999781954233'),
#   ('Boehm', '0.999778365405'),
#   ('Eero Saarinen', '0.999777609386'),
#   ('Xplorys', '0.999777383345'),
#   ('Labrazel', '0.999768215327'),
#   ('Stuart Crystal', '0.999763150661'),
#   ('Edland', '0.999762640994')],
#  [('ADAM by Adam Lippes', '1.0'),
#   ('Belle by Sigerson Morrison', '0.997405039304'),
#   ('Hanii Y', '0.997029161076'),
#   ('Shipley & Halmos', '0.996892213482'),
#   ('Adam', '0.996832343349'),
#   ('Sachin + Babi', '0.996546049575'),
#   ('Graham & Spencer', '0.996545532165'),
#   ('White + Warren', '0.996342211816'),
#   ('Laila Azhar', '0.996331697537'),
#   ('Kova And T', '0.996307847004')],
#  [('John Varvatos', '1.0'),
#   ('Y-3', '0.9883672469'),
#   ('Thomas Pink', '0.987282522466'),
#   ('Ben Sherman', '0.986681776287'),
#   ('Fred Perry', '0.986637566449'),
#   ('Hogan', '0.985253366541'),
#   ('Hugo', '0.985245055314'),
#   ('Prada Linea Rossa', '0.984692245672'),
#   ('Ermenegildo Zegna', '0.984565666651'),
#   ('Boss Orange', '0.984500125066')],
#  [('Coty', '1.0'),
#   ('Faces', '0.999927277993'),
#   ('Lillebaby', '0.999916427209'),
#   ('Mullins Square', '0.999915796222'),
#   ('Logoshirt', '0.99991247828'),
#   ('Space Bag', '0.999905585446'),
#   ('Little Giraffe', '0.999904429721'),
#   ('Duschdas', '0.999903589919'),
#   ('Colombo', '0.999903329822'),
#   ('Keepeez', '0.999900402134')],
#  [('Paul & Joe', '1.0'),
#   ('T-Bags', '0.791345191389'),
#   ('Oxford', '0.731565483877'),
#   ('Aqua', '0.725954441394'),
#   ('Rachel Pally', '0.718117584861'),
#   ('Teeze Me', '0.716945095096'),
#   ('Windsor', '0.663012453094'),
#   ('Jennifer Behr', '0.64512903335'),
#   ('Joie', '0.638798135873'),
#   ('Shoshanna', '0.634631352538')],
#  [('Ports 1961', '1.0'),
#   ('Erin Fetherston', '0.996014136891'),
#   ('Costume National', '0.994794878865'),
#   ('Pringle', '0.994646849929'),
#   ('CNC Costume National', '0.994370017336'),
#   ('Lela Rose', '0.994199259879'),
#   ('Paul & Joe Sister', '0.99382966513'),
#   ('Cynthia Rowley', '0.993528211609'),
#   ('Malene Birger', '0.993314505174'),
#   ('Akris', '0.993087961128')],
#  [('Dr. Brandt Skincare', '1.0'),
#   ('Murad', '0.990279501287'),
#   ('Shashi', '0.988677745388'),
#   ('Batiste', '0.988131113317'),
#   ('Cellex-C', '0.987782315156'),
#   ('Chantecaille', '0.983491360098'),
#   ('Forever Unique', '0.981449761188'),
#   ('Motif 56', '0.978845571908'),
#   ('Phyto', '0.977080478338'),
#   ('Soap & Glory', '0.976596013729')],
#  [('Repetto', '1.0'),
#   ('Mason Pearson', '0.921923235999'),
#   ('Trixxi', '0.89533863642'),
#   ('Santi', '0.875176211433'),
#   ('Chan Luu', '0.872498060197'),
#   ('Aveeno', '0.863039924908'),
#   ('Caparros', '0.854240553655'),
#   ('Elegantly Waisted', '0.853493056544'),
#   ('Motherhood', '0.851908639744'),
#   ('A Pea in the Pod', '0.849562307062')],
#  [('Falke', '1.0'),
#   ('Wayne', '0.998398101812'),
#   ('Lizzie Fortunato', '0.998386164837'),
#   ('Bird', '0.998332474138'),
#   ('Aiko', '0.998321911872'),
#   ('Edun', '0.998306501766'),
#   ('Gemma Redux', '0.998242075455'),
#   ('The Lake & Stars', '0.998239541541'),
#   ('Brochu Walker', '0.998172390003'),
#   ('Sophomore', '0.998167929225')],
#  [('Zimmermann', '1.0'),
#   ('Sass & Bide', '0.99766486235'),
#   ('Kimberly Ovitz', '0.997488633217'),
#   ('Willow', '0.997029462229'),
#   ('Brian Reyes', '0.99701334809'),
#   ('Kiki de Montparnasse', '0.996831515072'),
#   ('Shipley & Halmos', '0.996714426273'),
#   ('Richard Chai', '0.996598267608'),
#   ('Camilla And Marc', '0.996484261607'),
#   ('Jennifer Meyer', '0.996429021254')],
#  [('Parker', '1.0'),
#   ('Equipment', '0.925171963337'),
#   ('L-Space', '0.848461142487'),
#   ('BaubleBar', '0.80259090553'),
#   ('Aidan Mattox', '0.782884456396'),
#   ('Vince Camuto', '0.749009386847'),
#   ('Jane Tran', '0.732697650656'),
#   ('Issa', '0.721856488598'),
#   ('Sperry', '0.719638540442'),
#   ('Faliero Sarti', '0.71072835469')],
#  [('Mother', '1.0'),
#   ('MiH Jeans', '0.996176973508'),
#   ('Enza Costa', '0.995217291622'),
#   ('Cut25', '0.995207531757'),
#   ('Suno', '0.994835763734'),
#   ('Eberjey', '0.994749205387'),
#   ('Aiko', '0.994583840103'),
#   ('Theodora & Callum', '0.994444928983'),
#   ('Bloch', '0.99416372513'),
#   ('Dieppa Restrepo', '0.994010547671')],
#  [('Etoile Isabel Marant', '1.0'),
#   ('Carven', '0.994829200543'),
#   ('Maje', '0.993109103078'),
#   ('A.L.C.', '0.99261684409'),
#   ('IRO', '0.991453806609'),
#   ('Boy By Band Of Outsiders', '0.990578652976'),
#   ('Sandro', '0.989195982258'),
#   ('Acne', '0.988921346518'),
#   ('Rachel Comey', '0.98870919108'),
#   ('Band Of Outsiders', '0.988587787537')],
#  [('Fenton', '1.0'),
#   ('MySuelly', '0.99922679416'),
#   ('Dna', '0.999202275458'),
#   ('Hari', '0.999167228373'),
#   ('Ashley Pittman', '0.999142117275'),
#   ('Heimstone', '0.999138873971'),
#   ('Karla Colletto', '0.999137333602'),
#   ('Ila', '0.999136842287'),
#   ('Susan Foster', '0.99912422215'),
#   ('Lady Grey', '0.99910564521')],
#  [('Joie a la Plage', '1.0'),
#   ('Amanda Uprichard', '0.995539472034'),
#   ('Mason', '0.995088022956'),
#   ('Rebecca Beeson', '0.994698610098'),
#   ('Theodora & Callum', '0.994600168192'),
#   ('Eberjey', '0.994572590466'),
#   ('Graham & Spencer', '0.994413615793'),
#   ('Cut25', '0.994347777041'),
#   ('Wilt', '0.994314106813'),
#   ('Riller & Fount', '0.994227493878')],
#  [('Mezlan', '1.0'),
#   ('Ipath', '0.999840667632'),
#   ('H.S. Trask', '0.999768172385'),
#   ('Roar', '0.999731847819'),
#   ('Olivia Morris', '0.999722672202'),
#   ('Princess Linens', '0.99971471915'),
#   ('Dreamlets', '0.999708641475'),
#   ('Carriere', '0.999702228628'),
#   ('April Cornell', '0.999701695906'),
#   ('Spartan', '0.999699980721')],
#  [('Liz Lange', '1.0'),
#   ('Gossard', '0.99881145279'),
#   ('Bonne Bell', '0.998751997017'),
#   ('LaCrosse', '0.998712182846'),
#   ('Got2b', '0.998708718678'),
#   ('Palmers', '0.998700138382'),
#   ('KangaROOS', '0.998698317087'),
#   ('Red Carpet', '0.99867759377'),
#   ("L'anza", '0.998671478459'),
#   ("Nature's Gate", '0.998670161205')],
#  [('Diaper Dude', '1.0'),
#   ('Strida', '0.999944270579'),
#   ('Nyttja', '0.999944133802'),
#   ('Podee Inc.', '0.999943890373'),
#   ('Les Tout Petits', '0.999937580266'),
#   ('Tasha Tarno', '0.999936416532'),
#   ('W.A.C. Lighting', '0.999935780377'),
#   ('Duckie Brown', '0.999933105581'),
#   ('Ooh La La Mama', '0.999932602121'),
#   ('Banana Fish', '0.999931266543')],
#  [('Gryphon', '1.0'),
#   ('Mason by Michelle Mason', '0.997961595016'),
#   ('Smythe', '0.99748120973'),
#   ('Hanii Y', '0.996502631216'),
#   ('Jenni Kayne', '0.996163586406'),
#   ('Geren Ford', '0.996101985993'),
#   ('Sass & Bide', '0.996006996774'),
#   ('Zimmermann', '0.995577827913'),
#   ('ADAM by Adam Lippes', '0.995561994744'),
#   ('Kimberly Ovitz', '0.995441610191')],
#  [('Jenni Kayne', '1.0'),
#   ('Smythe', '0.996721741006'),
#   ('Lover', '0.996179224031'),
#   ('Gryphon', '0.996163586406'),
#   ('Shipley & Halmos', '0.996069810902'),
#   ('Kimberly Ovitz', '0.995995683982'),
#   ('JOSEPH', '0.99586095104'),
#   ('Kiki de Montparnasse', '0.995724917745'),
#   ('Zimmermann', '0.995720670505'),
#   ('Markus Lupfer', '0.99554842681')],
#  [('Zero Maria Cornejo', '1.0'),
#   ('Haider Ackermann', '0.996976093704'),
#   ('Junya Watanabe', '0.996864517807'),
#   ('Kiki de Montparnasse', '0.996643453314'),
#   ('By Malene Birger', '0.996507088389'),
#   ('Hussein Chalayan', '0.996460669703'),
#   ('Preen Line', '0.996161115321'),
#   ('JOSEPH', '0.996138496335'),
#   ('Markus Lupfer', '0.995826828236'),
#   ('Tsumori Chisato', '0.99579604839')],
#  [('Neutrogena', '1.0'),
#   ('Conair', '0.88569775929'),
#   ('Sally Beauty', '0.837019743373'),
#   ('Maybelline', '0.829067204598'),
#   ('Elle', '0.81988268617'),
#   ('Ulta', '0.816081490665'),
#   ('Billabong', '0.813013433177'),
#   ('O.p.i', '0.798314763466'),
#   ('Cover Girl', '0.783867240535'),
#   ('Revlon', '0.755330431842')],
#  [('Acne', '1.0'),
#   ('Etoile Isabel Marant', '0.988921346518'),
#   ('Rachel Comey', '0.985140584026'),
#   ('Maison Martin Margiela', '0.983470322719'),
#   ('Carven', '0.981608857638'),
#   ('A.L.C.', '0.980505781499'),
#   ('Comme des Garcons', '0.978444305831'),
#   ('Maje', '0.978256477683'),
#   ('Opening Ceremony', '0.97690912883'),
#   ('Ann Demeulemeester', '0.97594350242')],
#  [('TEXTILE Elizabeth and James', '1.0'),
#   ('Genetic Denim', '0.982581169271'),
#   ('Me & Ro', '0.98082567103'),
#   ('James Jeans', '0.979245188068'),
#   ('DL1961', '0.977948600227'),
#   ('Rich & Skinny', '0.976800174992'),
#   ('William Rast', '0.973115810396'),
#   ('Tart', '0.969316337276'),
#   ('Poetic Licence', '0.968113159267'),
#   ('Fresh', '0.967836481049')],
#  [('Carven', '1.0'),
#   ('Maje', '0.995273402969'),
#   ('Boy By Band Of Outsiders', '0.994840170671'),
#   ('Etoile Isabel Marant', '0.994829200543'),
#   ('A.L.C.', '0.992415167234'),
#   ('Band Of Outsiders', '0.99224876568'),
#   ('IRO', '0.991997920933'),
#   ('Sandro', '0.991849711444'),
#   ('Zero Maria Cornejo', '0.990152734612'),
#   ('Reed Krakoff', '0.989962161073')],
#  [("Theyskens' Theory", '1.0'),
#   ('A.L.C.', '0.958840935263'),
#   ('Etoile Isabel Marant', '0.958817026757'),
#   ('Carven', '0.957748498346'),
#   ('IRO', '0.955317517728'),
#   ('Maje', '0.955255107115'),
#   ('Sandro', '0.953883542637'),
#   ('Acne', '0.953023240348'),
#   ("L'Agence", '0.950240796052'),
#   ('Club Monaco', '0.949753366278')],
#  [('Golden Goose', '1.0'),
#   ('Ld Tuttle', '0.995946445426'),
#   ('VPL', '0.995867453857'),
#   ('Surface to Air', '0.995445447186'),
#   ('Mm6 By Maison Martin Margiela', '0.994998564161'),
#   ('Zero Maria Cornejo', '0.994136564046'),
#   ('Clu', '0.99380102535'),
#   ('Lover', '0.993663354441'),
#   ('Jenni Kayne', '0.993591393856'),
#   ('Giles & Brother', '0.993532643327')],
#  [('Izod', '1.0'),
#   ('Samsonite', '0.998340452557'),
#   ('Dickies', '0.998296701672'),
#   ('True Blue', '0.998270288377'),
#   ('Johnson & Johnson', '0.998148513763'),
#   ('Heritage Products', '0.99812189979'),
#   ('KangaROOS', '0.997910169003'),
#   ('Body Glove', '0.997908679219'),
#   ('K-Swiss', '0.997902058862'),
#   ('JPK', '0.997899825622')],
#  [('Paul Frank', '1.0'),
#   ('Swatch', '0.995608921004'),
#   ('Tokidoki', '0.995132705043'),
#   ('Jurlique', '0.994695044344'),
#   ('Le Sport Sac', '0.994559581913'),
#   ('Hello Kitty', '0.994548608765'),
#   ('Wrangler', '0.994311007368'),
#   ('Sisley Paris', '0.994238423245'),
#   ('Kipling', '0.994166176344'),
#   ('Birkenstock', '0.994161218438')],
#  [('Crocs', '1.0'),
#   ('Jan Marini Skin Research', '0.988803199918'),
#   ('Babyliss', '0.988678272096'),
#   ('bareMinerals', '0.98677947675'),
#   ('Becca', '0.985854962336'),
#   ('2Adorn', '0.985707462878'),
#   ('Olay', '0.985488885571'),
#   ('Jump', '0.985222052991'),
#   ('Elements', '0.985107921147'),
#   ('Hanes', '0.984498473251')],
#  ...]

# %%
predict('Kate Spade', model)
# Out:
# [('Kate Spade', '1.0'),
#  ('MICHAEL Michael Kors', '0.231801115111'),
#  ('Tory Burch', '0.228936263349'),
#  ('Lilly Pulitzer', '0.206599036834'),
#  ('Topshop', '0.187133167932'),
#  ('Christian Louboutin', '0.186116382761'),
#  ('Longchamp', '0.178716982117'),
#  ('Jeffrey Campbell', '0.172909921158'),
#  ('Marc by Marc Jacobs', '0.172517979584'),
#  ('Diane von Furstenberg', '0.15664884989')]

# %%
df.name.value_counts()
# Out:
# Marc by Marc Jacobs      119644
# Christian Louboutin      115665
# Burberry                 112238
# Gucci                    102444
# Marc Jacobs               93478
# Jimmy Choo                88514
# Prada                     86677
# Diane von Furstenberg     82491
# Yves Saint Laurent        82203
# Chloé                     82130
# Victoria's Secret         74553
# Forever 21                67716
# Juicy Couture             61811
# BCBG MAX AZRIA            59669
# GUESS                     55389
# Steve Madden              52627
# Michael Kors              51732
# Tory Burch                50774
# J.Crew                    50752
# Calvin Klein              48229
# Christian Dior            46688
# MICHAEL Michael Kors      45815
# Miu Miu                   43811
# Fendi                     37837
# Manolo Blahnik            36018
# Free People               34602
# Kate Spade                34039
# Coach                     33588
# Alexander McQueen         33421
# Alexander Wang            32484
#                           ...
# Catherine Rapetti             1
# Thinple                       1
# Deby Debo                     1
# Mad Imports                   1
# Triple Eight                  1
# Joshi                         1
# Nice Things                   1
# Olga Kapustina                1
# Banana Fish                   1
# Tibor Leathers                1
# Andrea Ventura                1
# British Knights               1
# Debuyer                       1
# Me To You                     1
# Tracy Matthews                1
# Dice Kayek                    1
# Dermenodex                    1
# Kelly Gerber                  1
# Piper and Forest              1
# Sanderson                     1
# Miquella                      1
# Zachary Prell                 1
# Amy Zerner                    1
# American Beauty               1
# Zita                          1
# Maytag                        1
# Iska                          1
# Mecchaniche Veloci            1
# Bravo New York                1
# Lichfield                     1
# Name: name, dtype: int64
